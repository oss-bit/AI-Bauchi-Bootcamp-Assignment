# %% [markdown]
# ## Implementationi of OCR with pytesseract

# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt


# Loading the image
image = cv2.imread(r"C:\Users\atsushi\Documents\text.png")

#displaying the orignal image
plt.imshow(image)
plt.title("Original Image")
plt.show()

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
threshold_img = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

# Use pytesseract to detect text
text = pytesseract.image_to_string(threshold_img)

# Print the text
print(text)
# Out:
# N0w1et’s save this painting into a_]PEG file named Test Image. Once it is
# saved, we can see a slightly darker border around the coloured squares. This
# is due to the compression of the file.
